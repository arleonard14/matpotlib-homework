# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import scipy.stats as st
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
study_merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
study_merge_df.count()
# Out:
# Mouse ID              1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_study_df = study_merge_df[["Mouse ID", "Drug Regimen", "Sex","Tumor Volume (mm3)", "Timepoint", "Sex",]]

# Change Index to Mouse ID
#df = mouse_study_df.set_index("Mouse ID")

df=mouse_study_df
df = df.drop_duplicates(subset=None, keep="first", inplace=False)

print(df)
# Out:
#      Mouse ID Drug Regimen   Sex  Tumor Volume (mm3)  Timepoint   Sex
# 0        k403     Ramicane  Male           45.000000          0  Male
# 1        k403     Ramicane  Male           38.825898          5  Male
# 2        k403     Ramicane  Male           35.014271         10  Male
# 3        k403     Ramicane  Male           34.223992         15  Male
# 4        k403     Ramicane  Male           32.997729         20  Male
# ...       ...          ...   ...                 ...        ...   ...
# 1888     z969     Naftisol  Male           63.145652         25  Male
# 1889     z969     Naftisol  Male           65.841013         30  Male
# 1890     z969     Naftisol  Male           69.176246         35  Male
# 1891     z969     Naftisol  Male           70.314904         40  Male
# 1892     z969     Naftisol  Male           73.867845         45  Male
#
# [1892 rows x 6 columns]

# %%
test=df.loc[df.duplicated (subset=["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
test
# Out:
# array(['g989'], dtype=object)

# %%
df["Mouse ID"].unique()
# Out:
# array(['k403', 's185', 'x401', 'm601', 'g791', 's508', 'f966', 'm546',
#        'z578', 'j913', 'u364', 'n364', 'y793', 'r554', 'm957', 'c758',
#        't565', 'a644', 'i177', 'j989', 'i738', 'a520', 'w914', 'r811',
#        'g288', 'i334', 'q610', 'd251', 'l897', 'c458', 'b742', 'b128',
#        'j246', 'a411', 'j119', 'w150', 'v923', 'g316', 's710', 'l509',
#        'r944', 'e662', 'u196', 'q597', 'a444', 'i557', 'r921', 'w678',
#        'y449', 'a203', 'a251', 'a262', 'a275', 'a366', 'a401', 'a457',
#        'a492', 'a577', 'a685', 'a699', 'a788', 'a818', 'a897', 'a963',
#        'b313', 'b447', 'b487', 'b559', 'b759', 'b879', 'c139', 'c264',
#        'c282', 'c302', 'c326', 'c402', 'c559', 'c580', 'c757', 'c766',
#        'c819', 'c832', 'c895', 'c927', 'd133', 'd164', 'd474', 'e213',
#        'e227', 'e291', 'e476', 'e584', 'f129', 'f234', 'f278', 'f345',
#        'f394', 'f436', 'f545', 'f932', 'f993', 'g107', 'g296', 'g497',
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
loc_mouse= df.loc["k403", "Drug Regimen"]
print("Using Loc: " + loc_mouse)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'k403'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-3d40a2ce3a9e> in <module>
#       1 # Optional: Get all the data for the duplicate mouse ID.
# ----> 2 loc_mouse= df.loc["k403", "Drug Regimen"]
# ...

# %%
loc_mouse=df.loc[df["Mouse ID"]=="g989"]

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# clean_df=df[df["Mouse ID"].isin(loc_mouse)==False]

clean_df=df[df["Mouse ID"].isin(test)==False]

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Tumor Volume (mm3)  Timepoint   Sex
# 0        k403     Ramicane  Male           45.000000          0  Male
# 1        k403     Ramicane  Male           38.825898          5  Male
# 2        k403     Ramicane  Male           35.014271         10  Male
# 3        k403     Ramicane  Male           34.223992         15  Male
# 4        k403     Ramicane  Male           32.997729         20  Male
# ...       ...          ...   ...                 ...        ...   ...
# 1888     z969     Naftisol  Male           63.145652         25  Male
# 1889     z969     Naftisol  Male           65.841013         30  Male
# 1890     z969     Naftisol  Male           69.176246         35  Male
# 1891     z969     Naftisol  Male           70.314904         40  Male
# 1892     z969     Naftisol  Male           73.867845         45  Male
#
# [1880 rows x 6 columns]

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_df["Mouse ID"].unique())
# Out:
# 248

# %%
len(df["Mouse ID"].unique())
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean_df= clean_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
median_df=clean_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
variance_df=clean_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
std_df=clean_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
sem_df=clean_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
count_df=clean_df.groupby(["Drug Regimen"]).count()["Tumor Volume (mm3)"]
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

summary_df = summary_df.rename(columns = {"Mouse ID" : "Trials"})

summary_df=pd.DataFrame({"Total": count_df, "Mean": mean_df, "Median": median_df, "Variance":variance_df, "Standard Deviation":std_df,
                         "SEM": sem_df})
summary_df
# Out:
#               Total       Mean     Median   Variance  Standard Deviation  \
# Drug Regimen
# Capomulin       230  40.675741  41.557809  24.947764            4.994774
# Ceftamin        178  52.591172  51.776157  39.290177            6.268188
# Infubinol       178  52.884795  51.820584  43.128684            6.567243
# Ketapril        188  55.235638  53.698743  68.553577            8.279709
# Naftisol        186  54.331565  52.509285  66.173479            8.134708
# Placebo         181  54.033581  52.288934  61.168083            7.821003
# Propriva        148  52.320930  50.446266  43.852013            6.622085
# Ramicane        228  40.216745  40.673236  23.486704            4.846308
# Stelasyn        181  54.233149  52.431737  59.450562            7.710419
# Zoniferol       182  53.236507  51.818479  48.533355            6.966589
#
#                    SEM
# Drug Regimen
# Capomulin     0.329346
# Ceftamin      0.469821
# Infubinol     0.492236
# Ketapril      0.603860
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_stats=clean_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
# Using the aggregation method, produce the same summary statistics in a single line
summary_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.bar_chart = df.plot.bar(x='lab', y='val', rot=0)
data = summary_df[["Total"]]


data.plot(kind="bar", facecolor="red", figsize=(6,4), legend=False)

# Set a title for the chart
plt.title("Drug Trials")

plt.show()
plt.tight_layout()

# %%
mouse_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Tumor Volume (mm3)  Timepoint   Sex
# 0        k403     Ramicane  Male           45.000000          0  Male
# 1        k403     Ramicane  Male           38.825898          5  Male
# 2        k403     Ramicane  Male           35.014271         10  Male
# 3        k403     Ramicane  Male           34.223992         15  Male
# 4        k403     Ramicane  Male           32.997729         20  Male
# ...       ...          ...   ...                 ...        ...   ...
# 1888     z969     Naftisol  Male           63.145652         25  Male
# 1889     z969     Naftisol  Male           65.841013         30  Male
# 1890     z969     Naftisol  Male           69.176246         35  Male
# 1891     z969     Naftisol  Male           70.314904         40  Male
# 1892     z969     Naftisol  Male           73.867845         45  Male
#
# [1893 rows x 6 columns]

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_group = study_merge_df.groupby('Sex')

# Create a dataframe counting the number of data points for each gender
gender_count = pd.DataFrame(gender_group['Sex'].count())

# View the groupby dataframe
gender_count.head()

# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.bar_chart = df.plot.bar(x='lab', y='val', rot=0)

# Set a title for the chart
# Out:
#         Sex
# Sex
# Female  935
# Male    958

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Use DataFrame.plot() in order to create a bar chart of the data
gender_count.plot(kind="pie",labels=gender_count.index.values, 
        autopct="%1.1f%%", shadow=True, startangle=90, subplots=True,legend=False)

# Set a title for the char
plt.title("Drug Trials")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
clean_df = study_merge_df.loc[(study_merge_df["Drug Regimen"] == "Capomulin") | (study_merge_df["Drug Regimen"] == "Ramicane") | (study_merge_df["Drug Regimen"] == "Ceftamin") | (study_merge_df["Drug Regimen"] == "Propriva"), :]

# Sort by Timpepoints
clean_df = filtered_df.sort_values("Timepoint", ascending = False)

clean_df = filtered_df.drop_duplicates(subset="Mouse ID", keep="first")
    
# Determine quartiles
quartiles = clean_df["Tumor Volume (mm3)"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

# Determine upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

Tumor_Volume = filtered_df["Tumor Volume (mm3)"]
fig1, ax1 = plt.subplots()
ax1.set_title("Tumor Volume of Mice")
ax1.set_ylabel("Tumor Volume")
ax1.boxplot(Tumor_Volume)
plt.show()

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Out:
#    Mouse ID Drug Regimen     Sex  Tumor Volume (mm3)  Timepoint
# 10     s185    Capomulin  Female           45.000000          0
# 11     s185    Capomulin  Female           43.878496          5
# 12     s185    Capomulin  Female           37.614948         10
# 13     s185    Capomulin  Female           38.177232         15
# 14     s185    Capomulin  Female           36.866876         20
# 15     s185    Capomulin  Female           33.949940         25
# 16     s185    Capomulin  Female           32.959671         30
# 17     s185    Capomulin  Female           28.328531         35
# 18     s185    Capomulin  Female           25.472143         40
# 19     s185    Capomulin  Female           23.343598         45

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-263-699293b7c51d> in <module>
#       1 # Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# ----> 2 mouse_weight = Capomulin_df.groupby(Capomulin_df["Mouse ID"])["Weight (g)"].mean()
#       3 tumor_volume = Capomulin_df.groupby(Capomulin_df["Mouse ID"])["Tumor Volume (mm3)"].mean()
#       4
#       5 # Create Scatter Plot with values calculated above
#
# NameError: name 'Capomulin_df' is not defined

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
